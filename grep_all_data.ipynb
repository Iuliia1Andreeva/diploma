# %%
import pandas as pd
from sqlalchemy import create_engine

engine = create_engine("mssql+pyodbc://SA:ANELE$1967_@localhost/YourDatabaseName?driver=ODBC+Driver+17+for+SQL+Server")


new_row_data = {
    'ReferenceID': -1,
    'Title': 'Materials Project',
}

new_row_df = pd.DataFrame([new_row_data])


new_row_df.index = [None]


table_name = 'LitReferences'


new_row_df.to_sql(table_name, con=engine, if_exists='append', index=False)


print("New row inserted successfully.")
# Out:
# New row inserted successfully.

# %%
import pandas as pd

# %%
elem_one = pd.read_csv("elem_one.csv")

# %%
elem_one.head()
elem_one = elem_one.drop(columns=["Unnamed: 0.1", "Unnamed: 0"])

# %%
elem_one.head()
# Out:
#    SubstanceID  NumElements El1  X1  El2  X2  El3  X3  El4  X4  ...  \
# 0            1            1   B NaN    0 NaN    0 NaN    0 NaN  ...
# 1            1            1   B NaN    0 NaN    0 NaN    0 NaN  ...
# 2            1            1   B NaN    0 NaN    0 NaN    0 NaN  ...
# 3            1            1   B NaN    0 NaN    0 NaN    0 NaN  ...
# 4            1            1   B NaN    0 NaN    0 NaN    0 NaN  ...
#
#            SpaceGroup Direction Temperature1  Temperature2      E1      E2  \
# 0                Pnnm       NaN          NaN           NaN  1.5349  1.5349
# 1  P4<sub>2</sub>/nnm       NaN          NaN           NaN  0.0000  0.0000
# 2               Fm-3m       NaN          NaN           NaN  0.0000  0.0000
# 3                R-3m       NaN          NaN           NaN  0.0000  0.0000
# 4                P2/c       NaN          NaN           NaN  0.5976  0.5976
#
#   IsCalculated  Comments  ReferenceID                    _DateGap
# ...

# %%
elem_one["ReferenceID"] = -1

# %%
elem_one.head()
# Out:
#    SubstanceID  NumElements El1  X1  El2  X2  El3  X3  El4  X4  ...  \
# 0            1            1   B NaN    0 NaN    0 NaN    0 NaN  ...
# 1            1            1   B NaN    0 NaN    0 NaN    0 NaN  ...
# 2            1            1   B NaN    0 NaN    0 NaN    0 NaN  ...
# 3            1            1   B NaN    0 NaN    0 NaN    0 NaN  ...
# 4            1            1   B NaN    0 NaN    0 NaN    0 NaN  ...
#
#            SpaceGroup Direction Temperature1  Temperature2      E1      E2  \
# 0                Pnnm       NaN          NaN           NaN  1.5349  1.5349
# 1  P4<sub>2</sub>/nnm       NaN          NaN           NaN  0.0000  0.0000
# 2               Fm-3m       NaN          NaN           NaN  0.0000  0.0000
# 3                R-3m       NaN          NaN           NaN  0.0000  0.0000
# 4                P2/c       NaN          NaN           NaN  0.5976  0.5976
#
#   IsCalculated  Comments  ReferenceID                    _DateGap
# ...

# %%
elem_one.columns
# Out:
# Index(['SubstanceID', 'NumElements', 'El1', 'X1', 'El2', 'X2', 'El3', 'X3',
#        'El4', 'X4', 'Elements', 'Compound', '_DateSubstances', 'Modification',
#        'CrystalSystem', 'StructureType', 'SpaceGroup', 'Direction',
#        'Temperature1', 'Temperature2', 'E1', 'E2', 'IsCalculated', 'Comments',
#        'ReferenceID', '_DateGap'],
#       dtype='object')

# %%
len(elem_one["Compound"])
# Out:
# 230

# %%
elem_two = pd.read_csv("elem_two.csv")

# %%
elem_two.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  SubstanceID  NumElements El1  X1 El2  X2  El3  \
# 0             0           0         3249            2  Cs   1  Au   1    0
# 1             1           1         3250            2  Li   3  Sb   1    0
# 2             2           2         3250            2  Li   3  Sb   1    0
# 3             3           3         3251            2  Li   3  Bi   1    0
# 4             4           4         3252            2  Na   3  As   1    0
#
#    X3  ...          SpaceGroup  Direction  Temperature1 Temperature2      E1  \
# 0 NaN  ...               Pm-3m        NaN           NaN          NaN  1.9857
# 1 NaN  ...  P6<sub>3</sub>/mmc        NaN           NaN          NaN  0.5664
# 2 NaN  ...               Fm-3m        NaN           NaN          NaN  0.8067
# 3 NaN  ...               Fm-3m        NaN           NaN          NaN  0.3799
# 4 NaN  ...  P6<sub>3</sub>/mmc        NaN           NaN          NaN  0.0922
#
# ...

# %%
elem_two = elem_two.drop(columns=["Unnamed: 0.1", "Unnamed: 0"])

# %%
len(elem_two["Compound"])
# Out:
# 2736

# %%
elem_three = pd.read_csv("elem_three.csv")
elem_three.head()
# Out:
#    Unnamed: 0  SubstanceID  NumElements El1  X1 El2  X2 El3  X3  El4  ...  \
# 0           0          484            3  Na   2  Rb   1  Sb   1  NaN  ...
# 1           1          485            3  Na   2  Cs   1  Sb   1  NaN  ...
# 2           2          486            3   K   2  Rb   1  Sb   1  NaN  ...
# 3           3          487            3  Rb   2  Cs   1  Sb   1  NaN  ...
# 4           4          488            3   K   2  Cs   1  Sb   1  NaN  ...
#
#    SpaceGroup  Direction Temperature1 Temperature2      E1      E2  \
# 0       Fm-3m        NaN          NaN          NaN  0.5682  0.5682
# 1        Immm        NaN          NaN          NaN  0.0001  0.0001
# 2       Fm-3m        NaN          NaN          NaN  0.6879  0.6879
# 3       Fm-3m        NaN          NaN          NaN  0.6602  0.6602
# 4       Fm-3m        NaN          NaN          NaN  0.8614  0.8614
#
#    IsCalculated Comments  ReferenceID                    _DateGap
# ...

# %%
elem_three = elem_three.drop(columns=["Unnamed: 0"])

# %%
elem_three.head()
# Out:
#    SubstanceID  NumElements El1  X1 El2  X2 El3  X3  El4  X4  ...  SpaceGroup  \
# 0          484            3  Na   2  Rb   1  Sb   1  NaN   0  ...       Fm-3m
# 1          485            3  Na   2  Cs   1  Sb   1  NaN   0  ...        Immm
# 2          486            3   K   2  Rb   1  Sb   1  NaN   0  ...       Fm-3m
# 3          487            3  Rb   2  Cs   1  Sb   1  NaN   0  ...       Fm-3m
# 4          488            3   K   2  Cs   1  Sb   1  NaN   0  ...       Fm-3m
#
#   Direction Temperature1  Temperature2      E1      E2 IsCalculated  Comments  \
# 0       NaN          NaN           NaN  0.5682  0.5682         True       NaN
# 1       NaN          NaN           NaN  0.0001  0.0001         True       NaN
# 2       NaN          NaN           NaN  0.6879  0.6879         True       NaN
# 3       NaN          NaN           NaN  0.6602  0.6602         True       NaN
# 4       NaN          NaN           NaN  0.8614  0.8614         True       NaN
#
# ...

# %%
len(elem_three["Compound"])
# Out:
# 1565

# %%
elem_four = pd.read_csv("elem_four.csv")
elem_four.head()
# Out:
#    Unnamed: 0  SubstanceID  NumElements El1  X1 El2  X2 El3  X3 El4  ...  \
# 0           0         1194            4  Cu   1  Pb   1  Bi   1   S  ...
# 1           1         1195            4  Ag   1  Pb   1  Bi   1   S  ...
# 2           2         1196            4  Rb   1  Cu   2   V   1   S  ...
# 3           3         1201            4  Fe   1   F   1  Sr   2   O  ...
# 4           4         1201            4  Fe   1   F   1  Sr   2   O  ...
#
#    SpaceGroup  Direction Temperature1 Temperature2      E1      E2  \
# 0        Pnma        NaN          NaN          NaN  0.6519  0.6519
# 1        Imm2        NaN          NaN          NaN  0.9371  0.9371
# 2        Ama2        NaN          NaN          NaN  1.1946  1.1946
# 3        I4mm        NaN          NaN          NaN  0.9804  0.9804
# 4      P4/nmm        NaN          NaN          NaN  1.2045  1.2045
#
#    IsCalculated Comments  ReferenceID                    _DateGap
# ...

# %%
elem_four = elem_four.drop(columns=["Unnamed: 0"])

# %%
len(elem_four["Compound"])
# Out:
# 900

# %%
elem_five = pd.read_csv("elem_five.csv")
elem_five.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  SubstanceID  NumElements  El1  X1  El2  X2  El3  \
# 0             0           0         2108            2  NaN NaN  NaN NaN  NaN
# 1             1           1         2171            2  NaN NaN  NaN NaN  NaN
# 2             2           2         2230            2  NaN NaN  NaN NaN  NaN
# 3             3           3         2902            2  NaN NaN  NaN NaN  NaN
# 4             4           4         2903            2  NaN NaN  NaN NaN  NaN
#
#    X3  ...        SpaceGroup  Direction  Temperature1 Temperature2      E1  \
# 0 NaN  ...  P2<sub>1</sub>/c        NaN           NaN          NaN  1.4803
# 1 NaN  ...                P1        NaN           NaN          NaN  2.2023
# 2 NaN  ...  P2<sub>1</sub>/c        NaN           NaN          NaN  5.6243
# 3 NaN  ...                P1        NaN           NaN          NaN  2.2200
# 4 NaN  ...                P1        NaN           NaN          NaN  2.2254
#
# ...

# %%
elem_five = elem_five.drop(columns=["Unnamed: 0.1", "Unnamed: 0"])

# %%
elem_five.head()
# Out:
#    SubstanceID  NumElements  El1  X1  El2  X2  El3  X3  El4  X4  ...  \
# 0         2108            2  NaN NaN  NaN NaN  NaN NaN  NaN NaN  ...
# 1         2171            2  NaN NaN  NaN NaN  NaN NaN  NaN NaN  ...
# 2         2230            2  NaN NaN  NaN NaN  NaN NaN  NaN NaN  ...
# 3         2902            2  NaN NaN  NaN NaN  NaN NaN  NaN NaN  ...
# 4         2903            2  NaN NaN  NaN NaN  NaN NaN  NaN NaN  ...
#
#          SpaceGroup Direction Temperature1  Temperature2      E1      E2  \
# 0  P2<sub>1</sub>/c       NaN          NaN           NaN  1.4803  1.4803
# 1                P1       NaN          NaN           NaN  2.2023  2.2023
# 2  P2<sub>1</sub>/c       NaN          NaN           NaN  5.6243  5.6243
# 3                P1       NaN          NaN           NaN  2.2200  2.2200
# 4                P1       NaN          NaN           NaN  2.2254  2.2254
#
#   IsCalculated  Comments  ReferenceID                    _DateGap
# ...

# %%
elem_five["X1"] = 0
elem_five["X2"] = 0
elem_five["X3"] = 0
elem_five["X4"] = 0
elem_five["ReferenceID"] = -1
elem_five.head()
# Out:
#    SubstanceID  NumElements  El1  X1  El2  X2  El3  X3  El4  X4  ...  \
# 0         2108            2  NaN   0  NaN   0  NaN   0  NaN   0  ...
# 1         2171            2  NaN   0  NaN   0  NaN   0  NaN   0  ...
# 2         2230            2  NaN   0  NaN   0  NaN   0  NaN   0  ...
# 3         2902            2  NaN   0  NaN   0  NaN   0  NaN   0  ...
# 4         2903            2  NaN   0  NaN   0  NaN   0  NaN   0  ...
#
#          SpaceGroup Direction Temperature1  Temperature2      E1      E2  \
# 0  P2<sub>1</sub>/c       NaN          NaN           NaN  1.4803  1.4803
# 1                P1       NaN          NaN           NaN  2.2023  2.2023
# 2  P2<sub>1</sub>/c       NaN          NaN           NaN  5.6243  5.6243
# 3                P1       NaN          NaN           NaN  2.2200  2.2200
# 4                P1       NaN          NaN           NaN  2.2254  2.2254
#
#   IsCalculated  Comments  ReferenceID                    _DateGap
# ...

# %%
len(elem_five["Compound"])
# Out:
# 13

# %%
pd.set_option('display.max_columns', None)
common_table = pd.concat([elem_one, elem_two, elem_three, elem_four, elem_five], join='inner', ignore_index=True).reset_index(drop=True)
common_table[common_table['NumElements'] == 2]
# Out:
#       SubstanceID  NumElements  El1   X1  El2   X2  El3   X3  El4   X4  \
# 230          3249            2   Cs  1.0   Au  1.0    0  NaN    0  NaN
# 231          3250            2   Li  3.0   Sb  1.0    0  NaN    0  NaN
# 232          3250            2   Li  3.0   Sb  1.0    0  NaN    0  NaN
# 233          3251            2   Li  3.0   Bi  1.0    0  NaN    0  NaN
# 234          3252            2   Na  3.0   As  1.0    0  NaN    0  NaN
# ...           ...          ...  ...  ...  ...  ...  ...  ...  ...  ...
# 5439         4322            2  NaN  0.0  NaN  0.0  NaN  0.0  NaN  0.0
# 5440         4520            2  NaN  0.0  NaN  0.0  NaN  0.0  NaN  0.0
# 5441         4528            2  NaN  0.0  NaN  0.0  NaN  0.0  NaN  0.0
# 5442         4922            2  NaN  0.0  NaN  0.0  NaN  0.0  NaN  0.0
# 5443         5840            2  NaN  0.0  NaN  0.0  NaN  0.0  NaN  0.0
#
#       Elements                                           Compound  \
# ...

# %%
for x in [elem_one, elem_two, elem_three, elem_four, elem_five]:
    print(x['El1'].isna().sum())
# Out:
# 0
# 0
# 0
# 0
# 13

# %%
elem_two['El1'].unique()
# Out:
# array(['Cs', 'Li', 'Na', 'K', 'Rb', 'Cu', 'Ag', 'Mg', 'Ca', 'Ba', 'Sr',
#        'Zn', 'Cd', 'Hg', 'Be', 'Ce', 'B', 'As', 'Sm', 'Eu', 'Yb', 'Al',
#        'Ga', 'In', 'Tl', 'Si', 'Mn', 'Ge', 'Sn', 'Pb', 'Zr', 'Hf', 'Ta',
#        'Sb', 'Bi', 'P', 'Nb', 'Cr', 'Mo', 'W', 'Te', 'Tc', 'Re', 'Ti',
#        'Rh', 'Pd', 'Pt', 'Ni', 'U', 'Fe', 'Sc', 'La', 'Nd', 'Y', 'Gd',
#        'Tb', 'Dy', 'Ho', 'Er', 'Tm', 'Lu', 'V', 'Co', 'Pr', 'Pu', 'Ru',
#        'Os', 'Ir', 'Th', 'C'], dtype=object)

# %%
elem_two['El1'].isna().sum()
# Out:
# 0

# %%
engine = create_engine("mssql+pyodbc://SA:ANELE$1967_@localhost/YourDatabaseName?driver=ODBC+Driver+17+for+SQL+Server")

query = "SELECT * FROM GapAll WHERE NumElements = 2;"
sql_two_elem = pd.read_sql(query, engine)

# Выведите первые несколько строк DataFrame для проверки
sql_two_elem.head()
sql_two_elem.to_csv('sql_two_elem.csv', index=True)

# %%
elem_two.columns
# Out:
# Index(['SubstanceID', 'NumElements', 'El1', 'X1', 'El2', 'X2', 'El3', 'X3',
#        'El4', 'X4', 'Elements', 'Compound', '_DateSubstances', 'Modification',
#        'CrystalSystem', 'StructureType', 'SpaceGroup', 'Direction',
#        'Temperature1', 'Temperature2', 'E1', 'E2', 'IsCalculated', 'Comments',
#        'ReferenceID', '_DateGap'],
#       dtype='object')

# %%
elem_two = elem_two.rename(columns={'_date': '_DateGap'})
elem_two.head()
# Out:
#    SubstanceID  NumElements El1  X1 El2  X2  El3  X3  El4  X4  Elements  \
# 0         3249            2  Cs   1  Au   1    0 NaN    0 NaN       NaN
# 1         3250            2  Li   3  Sb   1    0 NaN    0 NaN       NaN
# 2         3250            2  Li   3  Sb   1    0 NaN    0 NaN       NaN
# 3         3251            2  Li   3  Bi   1    0 NaN    0 NaN       NaN
# 4         3252            2  Na   3  As   1    0 NaN    0 NaN       NaN
#
#            Compound             _DateSubstances  Modification CrystalSystem  \
# 0              CsAu  2024-05-11 01:44:05.607296           NaN         cubic
# 1  Li<sub>3</sub>Sb  2024-05-11 01:44:05.607296           NaN     hexagonal
# 2  Li<sub>3</sub>Sb  2024-05-11 01:44:05.607296           NaN         cubic
# 3  Li<sub>3</sub>Bi  2024-05-11 01:44:05.607296           NaN         cubic
# 4  Na<sub>3</sub>As  2024-05-11 01:44:05.607296           NaN     hexagonal
#
# ...

# %%
import pandas as pd

combined_df = pd.concat([elem_two, elem_one], ignore_index=True)
combined_df.head(100)
# Out:
#     SubstanceID  NumElements El1   X1 El2   X2  El3  X3  El4  X4  Elements  \
# 0          3249            2  Cs  1.0  Au  1.0    0 NaN    0 NaN       NaN
# 1          3250            2  Li  3.0  Sb  1.0    0 NaN    0 NaN       NaN
# 2          3250            2  Li  3.0  Sb  1.0    0 NaN    0 NaN       NaN
# 3          3251            2  Li  3.0  Bi  1.0    0 NaN    0 NaN       NaN
# 4          3252            2  Na  3.0  As  1.0    0 NaN    0 NaN       NaN
# ..          ...          ...  ..  ...  ..  ...  ...  ..  ...  ..       ...
# 95         3284            2  Ag  1.0   I  1.0    0 NaN    0 NaN       NaN
# 96         3284            2  Ag  1.0   I  1.0    0 NaN    0 NaN       NaN
# 97         3284            2  Ag  1.0   I  1.0    0 NaN    0 NaN       NaN
# 98         3284            2  Ag  1.0   I  1.0    0 NaN    0 NaN       NaN
# 99         3284            2  Ag  1.0   I  1.0    0 NaN    0 NaN       NaN
#
# ...

# %%
new_df = pd.concat([combined_df, elem_three], ignore_index=True)

# %%
four = pd.concat([new_df, elem_four], ignore_index=True)

# %%
five = pd.concat([four, elem_five], ignore_index=True)

# %%
five['NumElements'].unique()
# Out:
# array([2, 1, 3, 4, 5])

# %%
new_df[new_df['NumElements'] == 1]['El1'].unique()
# Out:
# array(['Cs', 'Li', 'Na', 'K', 'Rb', 'Cu', 'Ag', 'Mg', 'Ca', 'Ba', 'Sr',
#        'Zn', 'Cd', 'Hg', 'Be', 'Ce', 'B', 'As', 'Sm', 'Eu', 'Yb', 'Al',
#        'Ga', 'In', 'Tl', 'Si', 'Mn', 'Ge', 'Sn', 'Pb', 'Zr', 'Hf', 'Ta',
#        'Sb', 'Bi', 'P', 'Nb', 'Cr', 'Mo', 'W', 'Te', 'Tc', 'Re', 'Ti',
#        'Rh', 'Pd', 'Pt', 'Ni', 'U', 'Fe', 'Sc', 'La', 'Nd', 'Y', 'Gd',
#        'Tb', 'Dy', 'Ho', 'Er', 'Tm', 'Lu', 'V', 'Co', 'Pr', 'Pu', 'Ru',
#        'Os', 'Ir', 'Th', 'C'], dtype=object)

# %%
five[five['NumElements'] == 1]
# Out:
#       SubstanceID  NumElements El1  X1 El2  X2 El3  X3  El4  X4  Elements  \
# 2736            1            1   B NaN   0 NaN   0 NaN  0.0 NaN       NaN
# 2737            1            1   B NaN   0 NaN   0 NaN  0.0 NaN       NaN
# 2738            1            1   B NaN   0 NaN   0 NaN  0.0 NaN       NaN
# 2739            1            1   B NaN   0 NaN   0 NaN  0.0 NaN       NaN
# 2740            1            1   B NaN   0 NaN   0 NaN  0.0 NaN       NaN
# ...           ...          ...  ..  ..  ..  ..  ..  ..  ...  ..       ...
# 2961           13            1  Bi NaN   0 NaN   0 NaN  0.0 NaN       NaN
# 2962           13            1  Bi NaN   0 NaN   0 NaN  0.0 NaN       NaN
# 2963           13            1  Bi NaN   0 NaN   0 NaN  0.0 NaN       NaN
# 2964         4948            1  Au NaN   0 NaN   0 NaN  0.0 NaN       NaN
# 2965         4948            1  Au NaN   0 NaN   0 NaN  0.0 NaN       NaN
#
#      Compound             _DateSubstances  Modification CrystalSystem  \
# ...

# %%
final_table_from_MP = five

# %%
final_table_from_MP.to_csv('final_table_from_MP.csv', index=True)

# %%
engine = create_engine("mssql+pyodbc://SA:ANELE$1967_@localhost/YourDatabaseName?driver=ODBC+Driver+17+for+SQL+Server")

query = "SELECT * FROM GapAll WHERE NumElements = 1;"
sql_one_elem = pd.read_sql(query, engine)
print(len(sql_one_elem['Compound']))

sql_one_elem = sql_one_elem[sql_one_elem['Compound'].isin(elem_one['Compound'])]
print(len(sql_one_elem['Compound']))
# Out:
# 198
# 198

# %%
model_table = pd.concat([final_table_from_MP, sql_one_elem], ignore_index=True)

# %%
len(model_table['Comments'])
# Out:
# 5642

# %%
engine = create_engine("mssql+pyodbc://SA:ANELE$1967_@localhost/YourDatabaseName?driver=ODBC+Driver+17+for+SQL+Server")

query = "SELECT * FROM GapAll WHERE NumElements = 2;"
sql_two_elem = pd.read_sql(query, engine)

print(len(sql_two_elem['Compound']))

sql_two_elem = sql_two_elem[sql_two_elem['Compound'].isin(elem_two['Compound'])]
print(len(sql_two_elem['Compound']))
# Out:
# 3247
# 3045

# %%
model_table = pd.concat([model_table, sql_two_elem], ignore_index=True)

# %%
len(model_table['Comments'])
# Out:
# 8687

# %%
engine = create_engine("mssql+pyodbc://SA:ANELE$1967_@localhost/YourDatabaseName?driver=ODBC+Driver+17+for+SQL+Server")

query = "SELECT * FROM GapAll WHERE NumElements = 3;"
sql_three_elem = pd.read_sql(query, engine)


print(len(sql_three_elem['Compound']))

sql_three_elem = sql_three_elem[sql_three_elem['Compound'].isin(elem_three['Compound'])]
print(len(sql_three_elem['Compound']))
# Out:
# 3539
# 2213

# %%
model_table = pd.concat([model_table, sql_three_elem], ignore_index=True)

# %%
len(model_table['Comments'])
# Out:
# 10900

# %%
engine = create_engine("mssql+pyodbc://SA:ANELE$1967_@localhost/YourDatabaseName?driver=ODBC+Driver+17+for+SQL+Server")

query = "SELECT * FROM GapAll WHERE NumElements = 4;"
sql_four_elem = pd.read_sql(query, engine)

print(len(sql_four_elem['Compound']))

sql_four_elem = sql_four_elem[sql_four_elem['Compound'].isin(elem_four['Compound'])]
print(len(sql_four_elem['Compound']))
# Out:
# 3682
# 991

# %%
model_table = pd.concat([model_table, sql_four_elem], ignore_index=True)

# %%
len(model_table['Comments'])
# Out:
# 11891

# %%
engine = create_engine("mssql+pyodbc://SA:ANELE$1967_@localhost/YourDatabaseName?driver=ODBC+Driver+17+for+SQL+Server")
query = "SELECT * FROM GapAll WHERE NumElements = 5;"
sql_five_elem = pd.read_sql(query, engine)

print(len(sql_five_elem['Compound']))

sql_five_elem = sql_five_elem[sql_five_elem['Compound'].isin(elem_five['Compound'])]
print(len(sql_five_elem['Compound']))
# Out:
# 407
# 22

# %%
model_table = pd.concat([model_table, sql_five_elem], ignore_index=True)

# %%
len(model_table['Comments'])
# Out:
# 11913

# %%
final_table_for_model = model_table.to_csv('final_table_for_model.csv', index=True, escapechar='\\')

# %%
model_table.head(100)
# Out:
#     SubstanceID  NumElements El1   X1 El2   X2 El3  X3  El4  X4 Elements  \
# 0          3249            2  Cs  1.0  Au  1.0   0 NaN  0.0 NaN      NaN
# 1          3250            2  Li  3.0  Sb  1.0   0 NaN  0.0 NaN      NaN
# 2          3250            2  Li  3.0  Sb  1.0   0 NaN  0.0 NaN      NaN
# 3          3251            2  Li  3.0  Bi  1.0   0 NaN  0.0 NaN      NaN
# 4          3252            2  Na  3.0  As  1.0   0 NaN  0.0 NaN      NaN
# ..          ...          ...  ..  ...  ..  ...  ..  ..  ...  ..      ...
# 95         3284            2  Ag  1.0   I  1.0   0 NaN  0.0 NaN      NaN
# 96         3284            2  Ag  1.0   I  1.0   0 NaN  0.0 NaN      NaN
# 97         3284            2  Ag  1.0   I  1.0   0 NaN  0.0 NaN      NaN
# 98         3284            2  Ag  1.0   I  1.0   0 NaN  0.0 NaN      NaN
# 99         3284            2  Ag  1.0   I  1.0   0 NaN  0.0 NaN      NaN
#
#             Compound             _DateSubstances Modification CrystalSystem  \
# ...
